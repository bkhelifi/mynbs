# %%
import gammapy
gammapy.__version__
# Out:
# '0.20.dev114+gf3b29861d'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import astropy.units as u
import warnings
from copy import deepcopy
from astropy.coordinates import SkyCoord, Angle
from astropy.time import Time
from pathlib import Path
import numpy as np
from regions import CircleSkyRegion
# from gammapy.utils.regions import make_region
from scipy.stats import norm,chi2
from gammapy.data import DataStore
from gammapy.datasets import (
    Datasets,
    MapDataset,
)
from gammapy.makers import (
    MapDatasetMaker,
    SafeMaskMaker,
    ReflectedRegionsBackgroundMaker,
    FoVBackgroundMaker,
    HessMapDatasetMaker
)
from gammapy.modeling.models import (
    SkyModel,
    PowerLawSpectralModel,
    ExpCutoffPowerLawSpectralModel,
    PointSpatialModel,
    GaussianSpatialModel,
    FoVBackgroundModel,
    Models,
)
from gammapy.modeling import Fit
from gammapy.maps import Map, MapAxis, WcsGeom
from gammapy.estimators import ExcessMapEstimator, LightCurveEstimator
# Out:
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_formats]

# %%
# Configure the logger, so that the 3D analysis isn't so chatty about what it's doing.
import logging

logging.basicConfig()
log = logging.getLogger("Crab-analysis")
log.setLevel(logging.INFO)
# See https://docs.python.org/3/library/logging.html#levels to get the different level of print-out
#log.setLevel(logging.ERROR)

# %%
BASE_DIR = "$CALDB/he_stereo_Prod17_Calib0834_thsq64"
SRC_POS = SkyCoord.from_name('Crab')
print(SRC_POS)
SELECTION_RADIUS = 1.2 * u.deg 
GEOM_WIDTH = 6 * u.deg
# OFFSET_MAX_CUTOUTS = 10 * u.deg
OFFSET_MAX_SAFE = 2 * u.deg
GEOM_BINSZ = 0.02 * u.deg
E_MIN = 0.5 * u.TeV
E_MAX = 150 * u.TeV
E_NBINS = 20
E_TRUE_MIN = 0.1 * u.TeV
E_TRUE_MAX = 200 * u.TeV
E_TRUE_NBINS = 50
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63308333, 22.0145)>

# %%
data_store = DataStore.from_dir(BASE_DIR)
data_store.info()
# Out:
# Data store:
# HDU index table:
# BASE_DIR: /home/khelifi/HESS/data/hap-16-03_fitscl7/Prod17_Calib0834/he_stereo_Prod17_Calib0834_thsq64
# Rows: 125922
# OBS_ID: 18092 -- 154591
# HDU_TYPE: ['aeff', 'bkg', 'edisp', 'events', 'gti', 'psf']
# HDU_CLASS: ['aeff_2d', 'bkg_2d', 'edisp_2d', 'events', 'gti', 'psf_table']
#
#
# Observation table:
# Observatory name: 'N/A'
# Number of observations: 21119

# %%
# Select observations
warnings.filterwarnings("ignore")
selection = dict(type='sky_circle', frame='galactic',
                 lon=SRC_POS.galactic.l,
                 lat=SRC_POS.galactic.b,
                 radius=SELECTION_RADIUS,
                 border=Angle(0.4, 'deg'))
selected_obs_table = data_store.obs_table.select_observations(selection)
observations = data_store.get_observations(selected_obs_table["OBS_ID"])
# Out:
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18517, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18526, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18529, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18561, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18564, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18566, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18870, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18871, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18874, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18875, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18885, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18886, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18889, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18890, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18927, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18942, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18945, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 18946, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23037, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23063, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23309, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23310, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23523, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23526, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23544, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23545, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23546, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23547, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23555, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23556, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23557, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23558, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23559, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23576, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23577, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23579, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23592, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23593, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23608, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23641, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23642, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23662, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23663, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23739, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23740, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23741, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23753, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23754, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 23756, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 24138, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 24139, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 29873, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 29874, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 35941, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 35956, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 35957, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 35992, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 36012, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 36013, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 36066, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 43038, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 43039, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 43424, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 43447, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 43489, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 43490, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 48399, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 48476, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 48682, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 48683, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 48717, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 48750, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54390, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54391, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54392, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54404, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54623, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54624, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54653, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54706, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54707, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54734, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54735, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54748, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54749, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54771, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54772, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54789, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 54809, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 60793, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 60794, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 60795, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80026, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80081, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80084, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80086, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80124, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80129, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80132, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80134, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80154, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80158, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80161, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80163, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80165, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80167, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80170, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80190, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80191, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80996, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80997, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 80998, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81022, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81023, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81078, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81083, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81086, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81089, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81133, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81134, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81135, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81136, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81160, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81664, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81666, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81667, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81725, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81731, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81794, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81841, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81847, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 81849, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82091, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82093, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82703, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82879, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 89354, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 89360, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 89367, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 89409, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90668, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101103, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101264, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102985, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103052, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103053, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103055, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103100, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 104226, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 104228, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135126, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135127, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135128, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135129, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135290, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 141898, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 141970, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 141971, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143164, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 144604, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 144605, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145077, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145086, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145775, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145778, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145782, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145948, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145958, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82038, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82725, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 82782, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 88951, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 88952, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 88973, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 89828, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90203, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90237, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90238, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90239, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90317, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90318, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90319, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90320, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90321, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90348, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90349, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90350, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90351, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90352, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90376, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90377, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90378, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90379, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90380, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90381, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90382, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90415, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90437, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90439, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90440, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90441, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90478, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 90564, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100452, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100453, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100454, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100553, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100554, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100555, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100573, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 100574, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101166, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101295, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101320, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101321, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 101451, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102293, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102402, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102474, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102575, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102576, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102987, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 102988, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103698, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103803, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103804, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103805, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103806, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103847, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103848, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103849, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103850, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103851, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 103956, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 117742, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 125715, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 125716, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 125717, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 125719, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 125757, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 125794, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 126115, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 126116, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 126536, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 126540, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127503, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127504, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127544, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127545, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127824, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127825, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127955, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127957, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127988, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127989, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127990, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 128016, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 128017, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135158, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135159, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135246, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135247, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135270, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135271, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135272, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135273, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135306, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135307, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135333, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135479, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135480, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135481, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135482, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135629, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135634, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135635, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135665, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135666, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 135667, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 137343, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 141861, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 141924, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142392, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142427, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142428, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142460, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142462, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142463, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142464, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142563, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142564, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142565, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142566, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142567, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142588, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142590, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142592, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142593, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142594, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142627, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142629, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142630, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142636, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142650, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142651, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142652, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142653, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142654, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142666, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142667, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142668, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142669, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142670, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142758, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142760, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142896, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142897, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142989, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 142990, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143050, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143082, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143134, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143135, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143136, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143137, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143161, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143165, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143210, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143211, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143212, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 143213, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 144011, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 145956, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154409, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154410, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154590, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154591, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127956, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 127958, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 144012, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154376, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154377, HDU_TYPE = rad_max, HDU_CLASS = None
# WARNING:gammapy.data.hdu_index_table:No HDU found matching: OBS_ID = 154378, HDU_TYPE = rad_max, HDU_CLASS = None

# %%
len(observations)
# Out:
# 343

# %%
# Geometry
# We now fix the energy axis for the counts map - (the reconstructed energy binning)
e_reco = MapAxis.from_energy_bounds(E_MIN,E_MAX, E_NBINS, unit="TeV", name="energy")

# We now fix the energy axis for the IRF maps (exposure, etc) - (the true energy binning)
e_true = MapAxis.from_energy_bounds(E_TRUE_MIN, E_TRUE_MAX, E_TRUE_NBINS, unit="TeV", name="energy_true")

# The WCS geometry - centered on the galactic center
geom = WcsGeom.create(skydir=SRC_POS, width=GEOM_WIDTH, binsz=GEOM_BINSZ, frame="galactic", axes=[e_reco])
print(geom)
# Out:
# WcsGeom
#
# 	axes       : ['lon', 'lat', 'energy']
# 	shape      : (300, 300, 20)
# 	ndim       : 3
# 	frame      : galactic
# 	projection : CAR
# 	center     : 184.6 deg, -5.8 deg
# 	width      : 6.0 deg x 6.0 deg
# 	wcs ref    : 184.6 deg, -5.8 deg

# %%
# Dataset configuration
dataset_empty = MapDataset.create(geom=geom, energy_axis_true=e_true)
stacked = MapDataset.create(geom=geom, energy_axis_true=e_true, name="Crab-stacked-TC")

# dataset_maker = MapDatasetMaker(selection=["counts", "background", "exposure", "psf", "edisp"])
# This is equivalent to ``maker = MapDatasetMaker()''
dataset_maker = HessMapDatasetMaker(selection=["counts", "background", "exposure", "psf", "edisp"])

safe_mask_maker = SafeMaskMaker(methods=["offset-max", "aeff-default","bkg-peak"], offset_max=OFFSET_MAX_SAFE)
# See the documentation of `~gammapy.makers.SafeMaskMaker` to get the full list of options
# This maker is important to handle properly the systematic errors of the instrument

circle = CircleSkyRegion(center=geom.center_skydir, radius=0.4 * u.deg)
exclusion_mask = geom.region_mask([circle], inside=False)

fov_bkg_maker = FoVBackgroundMaker(method="fit", exclusion_mask=exclusion_mask, min_counts=20)
fov_bkg_maker.default_spectral_model.parameters['tilt'].frozen = False

# %%
# Filter out problematic runs (i.e. runs that miss something)
stable = False
print("Number of observations before filtering: ", len(observations.ids))

while stable is not True:
    length_before = deepcopy(len(observations.ids))
    for obs in observations:
        try:
            obs.aeff
        except:
            idx = list(observations).index(obs)
            print("No aeff - Removing run ", observations.ids[idx])
            observations.pop(index=idx)
        try:
            obs.bkg
        except:
            idx = list(observations).index(obs)
            print("No bkg - Removing run ", observations.ids[idx])
            observations.pop(index=idx)
    length_after = deepcopy(len(observations.ids))        
    if length_after == length_before:
        stable = True
        
print("Number of observations after filtering: ", len(observations.ids))
# Out:
# Number of observations before filtering:  343
# Number of observations after filtering:  343

# %%
livetimes = []
for obs in observations:
    livetimes.append(obs.obs_info["LIVETIME"].value)
plt.hist(livetimes);

# %%
TC = []
for obs in observations:
    TC.append(obs.obs_info["TC"])
plt.hist(TC);

# %%
# Filter out low quality runs
stable = False
print("Number of observations before filtering: ", len(observations.ids))

while stable is not True:
    length_before = deepcopy(len(observations.ids))
    for obs in observations:
        quality = obs.obs_info["QUALITY"]
        if quality >= 1:
            idx = list(observations).index(obs)
            print(f"Bad quality ({quality}): ", observations.ids[idx])
            observations.pop(index=idx)
            continue
        livetime = obs.obs_info["LIVETIME"].value
        if livetime < 600:
            idx = list(observations).index(obs)
            print(f"Too short run ({livetime/60:.1f}min): ", observations.ids[idx])
            observations.pop(index=idx)
            continue
    length_after = deepcopy(len(observations.ids))        
    if length_after == length_before:
        stable = True
        
print("Number of observations after filtering: ", len(observations.ids))
# Out:
# Number of observations before filtering:  343
# Too short run (9.3min):  18517
# Too short run (9.6min):  135129
# Too short run (9.9min):  145086
# Too short run (9.3min):  90352
# Too short run (9.3min):  90382
# Too short run (6.8min):  145956
# Too short run (8.9min):  127958
# Too short run (5.2min):  144012
# Number of observations after filtering:  335

# %%
# energy_thresholds = []

# for obs in observations:
#     sep = SRC_POS.separation(obs.pointing_radec)
# #     aeff1D = obs.aeff.to_effective_area_table(offset=sep)
#     aeff1D = obs.aeff.evaluate(offset=sep)
#     aeff_max = np.max(aeff1D)
#     print(aeff_max)
#     energy_threshold = aeff1D.find_energy(0.1 * aeff_max)
#     energy_thresholds.append(energy_threshold.value) # in TeV

# %%
# plt.hist(np.asarray(energy_thresholds) * 1.0e3, bins=80);
# plt.xlabel('GeV');
# plt.xlim(200,2000)
# plt.title('E_safe histogram')
# #plt.savefig('esafe.png')

# %%
offsets = []
for obs in observations:
    offset = SRC_POS.separation(obs.pointing_radec)
    offsets.append(offset.value)
offsets = np.array(offsets)
plt.hist(offsets);

# %%
bin1 = offsets < 1.
bin2 = offsets > 1.

# %%
# We separate hess1 and hess1u runs, to be consistent with hap-hd 
obs_ids = []
first_hess1u_id = 127821
for obs in observations:
    obs_ids.append(obs.obs_id)
obs_ids = np.array(obs_ids)
hess1 = obs_ids < first_hess1u_id
hess1u = obs_ids >= first_hess1u_id

# %%
zeniths = []
for obs in observations:
    zenith = obs.pointing_zen
    zeniths.append(zenith.value)
zeniths = np.array(zeniths)
plt.hist(zeniths);

# %%
bina = zeniths < 50
binb = zeniths > 50

# %%
plt.scatter(zeniths[hess1], offsets[hess1], label="hess1")
plt.scatter(zeniths[hess1u], offsets[hess1u], label="hess1u")
plt.xlabel("Zen [deg]")
plt.ylabel("Offset [deg]")
plt.legend();

# %%
plt.scatter(zeniths[bin1], offsets[bin1], label="Offset<1d")
plt.scatter(zeniths[bin2], offsets[bin2], label="Offset>1d")
plt.xlabel("Zen [deg]")
plt.ylabel("Offset [deg]")
plt.legend();

# %%
plt.scatter(zeniths[bina], offsets[bina], label="Zen<50d")
plt.scatter(zeniths[binb], offsets[binb], label="Zen>50d")
plt.xlabel("Zen [deg]")
plt.ylabel("Offset [deg]")
plt.legend();

# %%
plt.scatter(zeniths[hess1&bina&bin1], offsets[hess1&bina&bin1], label="hess1_A")
plt.scatter(zeniths[hess1&bina&bin2], offsets[hess1&bina&bin2], label="hess1_B")
plt.scatter(zeniths[hess1&binb&bin2], offsets[hess1&binb&bin2], label="hess1_C")
plt.scatter(zeniths[hess1u], offsets[hess1u], label="hess1u")
plt.xlabel("Zen [deg]")
plt.ylabel("Offset [deg]")

plt.legend();

# %%
hess1_A = obs_ids[hess1&bina&bin1]
hess1_B = obs_ids[hess1&bina&bin2]
hess1_C = obs_ids[hess1&binb&bin2]
hess1U = obs_ids[hess1u]

obs_bins = {
    "hess1_A" : list(hess1_A),
    "hess1_B" : list(hess1_B),
    "hess1_C" : list(hess1_C),
    "hess1u" : list(hess1U),
}

# %% [markdown]
# ## Make the data reduction

# %%
# %%time
warnings.filterwarnings("ignore")
datasets = Datasets() # It will contain a list of MapDatasets

for obs in observations:
#     obs_TC = obs.obs_info["TC"]
    dataset = dataset_maker.run(dataset_empty.copy(name=f"obs-{obs.obs_id}"), obs)
    
    dataset = safe_mask_maker.run(dataset, obs)
    dataset = fov_bkg_maker.run(dataset)
    rel_err = dataset.background_model.spectral_model.norm.error/dataset.background_model.spectral_model.norm.value
    if rel_err > 0.15:
        print(f"TOO big bkg norm error for obs {obs.obs_id}: {dataset.background_model.spectral_model.norm.value:.2f} \
         +/- {dataset.background_model.spectral_model.norm.error:.2f}")
        continue
    stacked.stack(dataset)
    datasets.append(dataset)
    # print(f"{obs.obs_id}: {rel_err:.2f}")
    # if obs.obs_id>20000:
    #     break
    if obs.obs_id>125000:
        break
print(f"Number of retained observations: {len(datasets)}\n")
# Out:
# Number of retained observations: 150
#
# CPU times: user 17min 55s, sys: 5min 55s, total: 23min 50s
# Wall time: 24min 15s

# %%
print(stacked)
# Out:
# MapDataset
# ----------
#
#   Name                            : Crab-stacked-TC
#
#   Total counts                    : 169030
#   Total background counts         : 152872.45
#   Total excess counts             : 16157.55
#
#   Predicted counts                : 152872.43
#   Predicted background counts     : 152872.45
#   Predicted excess counts         : nan
#
#   Exposure min                    : 5.72e-02 m2 s
#   Exposure max                    : 2.30e+11 m2 s
#
#   Number of total bins            : 1800000
#   Number of fit bins              : 1244518
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : nan
#
#   Number of models                : 0
#   Number of parameters            : 0
#   Number of free parameters       : 0

# %%
stacked.counts.sum_over_axes().smooth(0.05 * u.deg).plot(stretch="sqrt", add_cbar=True);

# %%
path = Path("Crab_withTC")
path.mkdir(exist_ok=True)

filename = path / "crab-TC-stacked-dataset.fits.gz"
stacked.write(filename, overwrite=True)
filename = path / "crab-TC-datasets.fits.gz"
datasets.write(filename, overwrite=True)

# %%
# path = Path("Crab_withTC")
# path.mkdir(exist_ok=True)

# filename = path / "crab-TC-stacked-dataset.fits.gz"
# stacked = MapDataset.read(filename)
# filename = path / "crab-TC-datasets.fits.gz"
# datasets = Datasets.read(filename)

# %%
# stacked.edisp.

# %% [markdown]
# ## Make the fit

# %%
# spatial_model = PointSpatialModel(lon_0=SRC_POS.ra, lat_0=SRC_POS.dec, frame="icrs")
spatial_model = GaussianSpatialModel(lon_0=SRC_POS.ra, lat_0=SRC_POS.dec, frame="icrs",
                                     sigma="0.03 deg", e=0., phi=Angle("0 deg"))

expo = True
if not expo:
    spectral_model = PowerLawSpectralModel(
        index=2.702,
        amplitude=4.712e-11 * u.Unit("1 / (cm2 s TeV)"),
        reference=1 * u.TeV,
    )
else:
    spectral_model = ExpCutoffPowerLawSpectralModel(
        index=2.4,
        amplitude=4.0e-11 * u.Unit("1 / (cm2 s TeV)"),
        lambda_=1./(10*u.TeV),
        reference=1 * u.TeV,
    )
    
sky_model = SkyModel(
    spatial_model=spatial_model, spectral_model=spectral_model, name="crab"
)

bkg_model = FoVBackgroundModel(dataset_name=stacked.name)

# %%
emin_fit = 2.
emax_fit = 40.
coords = stacked.counts.geom.get_coord()
mask_energy = np.logical_and(coords["energy"] < emax_fit * u.TeV, coords["energy"] >= emin_fit * u.TeV)
stacked.mask_fit = Map.from_geom(geom=stacked.counts.geom, data=mask_energy)

# %%
stacked.models = [sky_model, bkg_model]
print(stacked)
# Out:
# MapDataset
# ----------
#
#   Name                            : Crab-stacked-TC
#
#   Total counts                    : 169030
#   Total background counts         : 152872.45
#   Total excess counts             : 16157.55
#
#   Predicted counts                : 164302.56
#   Predicted background counts     : 152872.43
#   Predicted excess counts         : 11430.13
#
#   Exposure min                    : 5.72e-02 m2 s
#   Exposure max                    : 2.30e+11 m2 s
#
#   Number of total bins            : 1800000
#   Number of fit bins              : 732210
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : 383251.50
#
#   Number of models                : 2
#   Number of parameters            : 13
#   Number of free parameters       : 7
#
#   Component 0: SkyModel
#
#     Name                      : crab
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      2.400   +/-    0.00
#       amplitude                     :   4.00e-11   +/- 0.0e+00 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.100   +/-    0.00 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     83.633   +/-    0.00 deg
#       lat_0                         :     22.015   +/-    0.00 deg
#       sigma                         :      0.030   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : Crab-stacked-TC-bkg
#     Datasets names            : ['Crab-stacked-TC']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      1.000   +/-    0.00
#       tilt                  (frozen):      0.000
#       reference             (frozen):      1.000       TeV

# %%
# %%time
fit = Fit(optimize_opts={"print_level": 1})
result = fit.run([stacked])
# Out:
# WARNING:gammapy.irf.core:Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63308333, 18.97106668)> is outside valid IRF map range, using nearest IRF defined within
# WARNING:gammapy.irf.core:Position <SkyCoord (ICRS): (ra, dec) in deg
#     (83.63308333, 18.97106668)> is outside valid IRF map range, using nearest IRF defined within
# CPU times: user 55.9 s, sys: 8.73 s, total: 1min 4s
# Wall time: 1min 6s

# %%
print(stacked)
# Out:
# MapDataset
# ----------
#
#   Name                            : Crab-stacked-TC
#
#   Total counts                    : 169030
#   Total background counts         : 152872.45
#   Total excess counts             : 16157.55
#
#   Predicted counts                : 165740.17
#   Predicted background counts     : 150601.02
#   Predicted excess counts         : 15139.15
#
#   Exposure min                    : 5.72e-02 m2 s
#   Exposure max                    : 2.30e+11 m2 s
#
#   Number of total bins            : 1800000
#   Number of fit bins              : 732210
#
#   Fit statistic type              : cash
#   Fit statistic value (-2 log(L)) : 378256.86
#
#   Number of models                : 2
#   Number of parameters            : 13
#   Number of free parameters       : 7
#
#   Component 0: SkyModel
#
#     Name                      : crab
#     Datasets names            : None
#     Spectral model type       : ExpCutoffPowerLawSpectralModel
#     Spatial  model type       : GaussianSpatialModel
#     Temporal model type       :
#     Parameters:
#       index                         :      1.721   +/-    0.04
#       amplitude                     :   1.80e-11   +/- 8.7e-13 1 / (cm2 s TeV)
#       reference             (frozen):      1.000       TeV
#       lambda_                       :      0.048   +/-    0.00 1 / TeV
#       alpha                 (frozen):      1.000
#       lon_0                         :     83.630   +/-    0.00 deg
#       lat_0                         :     22.022   +/-    0.00 deg
#       sigma                         :      0.021   +/-    0.00 deg
#       e                     (frozen):      0.000
#       phi                   (frozen):      0.000       deg
#
#   Component 1: FoVBackgroundModel
#
#     Name                      : Crab-stacked-TC-bkg
#     Datasets names            : ['Crab-stacked-TC']
#     Spectral model type       : PowerLawNormSpectralModel
#     Parameters:
#       norm                          :      0.985   +/-    0.00
#       tilt                  (frozen):      0.000
#       reference             (frozen):      1.000       TeV

# %%
print(result)
# Out:
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 336
# 	total stat : 378256.86
#
# CovarianceResult
#
# 	backend    : minuit
# 	method     : hesse
# 	success    : True
# 	message    : Hesse terminated successfully.

# %%
stacked.models.to_parameters_table()
# Out:
# <Table length=13>
#        model          type      name     value         unit        error      min        max    frozen link
#        str19          str8      str9    float64       str14       float64   float64    float64   bool  str1
# ------------------- -------- --------- ---------- -------------- --------- ---------- --------- ------ ----
#                crab spectral     index 1.7215e+00                4.290e-02        nan       nan  False
#                crab spectral amplitude 1.8010e-11 cm-2 s-1 TeV-1 8.728e-13        nan       nan  False
#                crab spectral reference 1.0000e+00            TeV 0.000e+00        nan       nan   True
#                crab spectral   lambda_ 4.8124e-02          TeV-1 4.524e-03        nan       nan  False
#                crab spectral     alpha 1.0000e+00                0.000e+00        nan       nan   True
#                crab  spatial     lon_0 8.3630e+01            deg 7.435e-04        nan       nan  False
#                crab  spatial     lat_0 2.2022e+01            deg 6.919e-04 -9.000e+01 9.000e+01  False
#                crab  spatial     sigma 2.0543e-02            deg 8.806e-04  0.000e+00       nan  False
#                crab  spatial         e 0.0000e+00                0.000e+00  0.000e+00 1.000e+00   True
#                crab  spatial       phi 0.0000e+00            deg 0.000e+00        nan       nan   True
# Crab-stacked-TC-bkg spectral      norm 9.8514e-01                3.363e-03        nan       nan  False
# Crab-stacked-TC-bkg spectral      tilt 0.0000e+00                0.000e+00        nan       nan   True
# Crab-stacked-TC-bkg spectral reference 1.0000e+00            TeV 0.000e+00        nan       nan   True

# %%
# HESS Crab paper: from 440GeV to 40TeV
crab_exp = ExpCutoffPowerLawSpectralModel(
    index=2.37,
    amplitude=3.76e-11 * u.Unit("1 / (cm2 s TeV)"),
    lambda_=1./(11.2*u.TeV),
    reference=1 * u.TeV,
)
crab_exp.parameters["index"].error = 0.03
crab_exp.parameters["amplitude"].error = 0.07e-11* u.Unit("1 / (cm2 s TeV)")
crab_exp.parameters["lambda_"].error = 2.1*(crab_exp.parameters["lambda_"].value)**2* u.Unit("1 / (TeV)")

crab_pl = PowerLawSpectralModel(
    index=2.63,
    amplitude=3.45e-11 * u.Unit("1 / (cm2 s TeV)"),
    reference=1 * u.TeV,
)
crab_pl.parameters["index"].error = 0.01
crab_pl.parameters["amplitude"].error = 0.05e-11* u.Unit("1 / (cm2 s TeV)")

# %%
if expo:
    print(1/result.parameters['lambda_'].value*u.TeV)
    print("2006 papers:")
    print(crab_exp)
else:
    print("2006 papers:")
    print(crab_pl)
    print("MdN:") #https://hess-confluence.desy.de/confluence/display/~mzacharias/Crab+Test+September+2020?preview=/201162960/201392308/Crab_Nebula_ModelPlus_HESSI_Stereo_Std_Spectrum_SpectrumPowerLaw.png
    print("index: 2.62 +/- 0.03")
    print("amplitude: 3.73e-11 +/- 1.25e-12 cm-2 s-1 TeV-1")
# Out:
# 20.779848763336048 TeV
# 2006 papers:
# ExpCutoffPowerLawSpectralModel
#
#   type      name     value         unit        error   min max frozen link
# -------- --------- ---------- -------------- --------- --- --- ------ ----
# spectral     index 2.3700e+00                3.000e-02 nan nan  False
# spectral amplitude 3.7600e-11 cm-2 s-1 TeV-1 7.000e-13 nan nan  False
# spectral reference 1.0000e+00            TeV 0.000e+00 nan nan   True
# spectral   lambda_ 8.9286e-02          TeV-1 1.674e-02 nan nan  False
# spectral     alpha 1.0000e+00                0.000e+00 nan nan   True

# %%
stacked.plot_residuals_spatial(method="diff/sqrt(model)", vmin=-0.5, vmax=0.5);

# %%
region = CircleSkyRegion(
    center=SkyCoord(SRC_POS.ra, SRC_POS.dec), radius=0.5 * u.deg
)
stacked.plot_residuals(
    kwargs_spatial=dict(method="diff/sqrt(model)", vmin=-0.5, vmax=0.5),
    kwargs_spectral=dict(region=region),
);

# %%
sp_stacked = stacked.to_spectrum_dataset(on_region=region)
sp_stacked.models = sky_model
ax_spectrum, ax_residuals = sp_stacked.plot_fit()
# ax_spectrum.set_ylim(10, 12000)
sp_stacked.plot_masks(ax=ax_spectrum);

spec = sky_model.spectral_model

# %%
energy_bounds = [emin_fit, emax_fit] * u.TeV
def plot_spectrum(model, result, label, color):
    spec = model.spectral_model
#     energy_bounds = [0.3, 10] * u.TeV
    ax = spec.plot(
        energy_bounds=energy_bounds, energy_power=2, label=label, color=color
    )
    spec.plot_error(energy_bounds=energy_bounds, energy_power=2, color=color)
    return ax

# %%
ax = plot_spectrum(sky_model, result, label="stacked", color="tab:blue")
# plot_spectrum(model_joint, result_joint, label="joint", color="tab:orange")
crab_exp.plot(ax=ax, energy_bounds=energy_bounds, energy_power=2, color='black', label='PL+exp (2006)')
crab_pl.plot(ax=ax, energy_bounds=energy_bounds, energy_power=2, color='black', label='PL (2006)')
plt.legend();

# %% [markdown]
# ## Light Curve

# %%
time_intervals = [
    Time(['2004-01-01 00:00:00','2004-12-31 00:00:00'], scale="utc"),
    Time(['2005-01-01 00:00:00','2005-12-31 00:00:00'], scale="utc"),
    Time(['2006-01-01 00:00:00','2006-12-31 00:00:00'], scale="utc"),
    Time(['2007-01-01 00:00:00','2007-12-31 00:00:00'], scale="utc"),
    Time(['2008-01-01 00:00:00','2008-12-31 00:00:00'], scale="utc"),
    Time(['2009-01-01 00:00:00','2009-12-31 00:00:00'], scale="utc"),
    Time(['2010-01-01 00:00:00','2010-12-31 00:00:00'], scale="utc"),
    Time(['2011-01-01 00:00:00','2011-12-31 00:00:00'], scale="utc"),
    Time(['2012-01-01 00:00:00','2012-12-31 00:00:00'], scale="utc"),
    Time(['2013-01-01 00:00:00','2013-12-31 00:00:00'], scale="utc"),
    Time(['2014-01-01 00:00:00','2014-12-31 00:00:00'], scale="utc"),
    Time(['2015-01-01 00:00:00','2015-12-31 00:00:00'], scale="utc"),
    Time(['2016-01-01 00:00:00','2016-12-31 00:00:00'], scale="utc"),
    Time(['2017-01-01 00:00:00','2017-12-31 00:00:00'], scale="utc"),
    Time(['2018-01-01 00:00:00','2018-12-31 00:00:00'], scale="utc"),
    Time(['2019-01-01 00:00:00','2019-12-31 00:00:00'], scale="utc"),
]

lc_maker_3d = LightCurveEstimator(
    energy_edges=[emin_fit, emax_fit] * u.TeV, time_intervals=time_intervals,
    source="crab", reoptimize=False, selection_optional="all",
)

for ds in datasets:
    ds_model = ds.models[0]
    ds.models = [ds_model, sky_model]

# %%
# %%time
lc_3d = lc_maker_3d.run(datasets)
# Out:
# CPU times: user 20min 31s, sys: 2min 47s, total: 23min 18s
# Wall time: 24min 11s

# %%
lc_3d.plot(axis_name="time");

# %%
# lc_3d.plot(color="tab:orange")
# ax = lc_3d.plot_ts_profiles()
# ax.set_ylim(1e-12, 3e-12);

# %%
table = lc_3d.to_table(format="lightcurve", sed_type="flux")
table["time_min", "time_max", "e_min", "e_max", "flux", "flux_err"]
# Out:
# <Table length=11>
#      time_min           time_max          e_min [1]          e_max [1]            flux [1]             flux_err [1]
#                                              TeV                TeV             1 / (cm2 s)            1 / (cm2 s)
#      float64            float64            float64            float64             float64                float64
# ------------------ ------------------ ------------------ ----------------- ---------------------- ----------------------
#  53005.00074287037  53370.00074287037 2.0808957251439084 36.04217121202131  9.339006328005274e-12 1.8281949561629943e-13
#  53371.00074287037  53735.00074287037 2.0808957251439084 36.04217121202131 1.1274338492030374e-11  4.391903620165567e-13
#  53736.00075444444  54100.00075444444 2.0808957251439084 36.04217121202131  7.867340053896425e-12  4.235183700522004e-13
#  54101.00075444444  54465.00075444444 2.0808957251439084 36.04217121202131  1.133578803545832e-11  5.735806524216244e-13
#  54466.00075444444  54831.00075444444 2.0808957251439084 36.04217121202131  9.693057271088202e-12  6.039437066730615e-13
# 54832.000766018515 55196.000766018515 2.0808957251439084 36.04217121202131   9.07483486698256e-12  3.220066762760692e-13
# 55197.000766018515 55561.000766018515 2.0808957251439084 36.04217121202131  3.835675414031915e-12  3.988606787043467e-13
#  56293.00077759259  56657.00077759259 2.0808957251439084 36.04217121202131  9.206228641423656e-12 1.8104572680973287e-13
#  56658.00077759259  57022.00077759259 2.0808957251439084 36.04217121202131 1.0455731156118336e-11   9.36022472956582e-13
#  57023.00077759259  57387.00078916666 2.0808957251439084 36.04217121202131  9.545423371434587e-12  4.821856726419944e-13
#  57754.00080074074  58118.00080074074 2.0808957251439084 36.04217121202131  9.647895651460808e-12 1.0979226490907913e-12

# %%
stacked
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_108111/875444265.py in <module>
# ----> 1 stacked
#
# NameError: name 'stacked' is not defined
